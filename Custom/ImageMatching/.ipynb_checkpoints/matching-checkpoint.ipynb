# %%
# Import all libraries here
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def MatchImage(testImg, matchImage):
    imageMatch = False
    img_gray = cv2.cvtColor(testImg, cv2.COLOR_BGR2GRAY)
    w, h = matchImage.shape[::-1]
    res = cv2.matchTemplate(img_gray,matchImage,cv2.TM_CCOEFF_NORMED)
    loc = np.where( res >= threshold)
    for pt in zip(*loc[::-1]):
        cv2.rectangle(testImg, pt, (pt[0] + w, pt[1] + h), (0,0,255), 2)
        imageMatch = True
    if imageMatch == True :
        plt.imshow(testImg)
        plt.show()
    return imageMatch

# %%
iteration = 8
i = 1
img_rgb = cv2.imread('images/test6.jpg')


while i <= iteration:
    template = cv2.imread('images/canola' + str(i) + '.jpg',0)
    threshold = 0.8
    if MatchImage(img_rgb, template) == True :
        plt.imshow(template)
        plt.show()
        break;
    i = i + 1

#cv2.imwrite('res.png',img_rgb)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-126-b7bafa50d2d9> in <module>()
#       8     template = cv2.imread('images/canola' + str(i) + '.jpg',0)
#       9     threshold = 0.8
# ---> 10     if MatchImage(img_rgb, template) == True :
#      11         plt.imshow(template)
#      12         plt.show()
#
# <ipython-input-121-2880703cf983> in MatchImage(testImg, matchImage)
#       3     img_gray = cv2.cvtColor(testImg, cv2.COLOR_BGR2GRAY)
#       4     w, h = matchImage.shape[::-1]
# ----> 5     res = cv2.matchTemplate(img_gray,matchImage,cv2.TM_CCOEFF_NORMED)
#       6     loc = np.where( res >= threshold)
#       7     for pt in zip(*loc[::-1]):
#
# ...

# %%
import numpy as np
import argparse
import cv2
 

image = cv2.imread("images/test2.jpg")


#find the edges of the leaf in the image
#pts = np.array(eval(args["coords"]), dtype = "float32")
 
# apply the four point tranform to obtain a "birds eye view" of
# the image
#warped = four_point_transform(image, pts)
 
# show the original and warped images
plt.imshow(image)
plt.show()
#cv2.imshow("Warped", warped)
