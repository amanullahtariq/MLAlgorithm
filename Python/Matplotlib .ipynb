# %%
import matplotlib.pyplot as plt
x = [3,4,5]
y = [6,7,8]
plt.plot(x,y)
plt.xlabel('X-axis')
plt.label('Y-axis')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-34131c728536> in <module>()
#       4 plt.plot(x,y)
#       5 plt.xlabel('X-axis')
# ----> 6 plt.label('Y-axis')
#       7 #plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'
